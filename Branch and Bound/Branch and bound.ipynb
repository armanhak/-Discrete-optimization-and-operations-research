# %% [markdown]
# ======================================== System Information ==========================================<BR>
# System: Windows<BR>
# Release: 10<BR>
# Version: 10.0.19041<BR>
# Machine: AMD64<BR>
# Processor: Intel64 Family 6 Model 142 Stepping 10, GenuineIntel<BR>
# ======================================== CPU Info ==================================================<BR>
# CPU model name: Intel(R) Core(TM) i5-8250U CPU @ 1.60GHZ 1.80GHZ<BR>
# Physical cores: 4<BR>
# Total cores: 8<BR>
# ======================================== RAM Info ==================================================<BR>
# RAM: 8.00 GB

# %% [markdown]
# # Max clique. Branch and Bound

# %%
from my_module import CplexSolver, BnBSolver
import pandas as pd
from tqdm.notebook import tqdm
with open('file_names.txt', 'r') as f:
    files = [path.strip() for path in f.readlines()]
res = {'graph':[], 'clique':[], 'time (sec)':[], 'Timeout':[], 'Timeout (sec)':[]}

# %%
# %%time    
for path in tqdm(files): 
    cplex_solver = CplexSolver(path)
    bnb = BnBSolver(graph = cplex_solver.graph, 
                    solver=cplex_solver.solver,
                    time_limit=3600
                   )
    r = bnb.run_bnb()
    res['graph'].append(path.replace('DIMACS_all_ascii/', ''))
    res['clique'].append(bnb.MAX_CLIQUE)
    res['time (sec)'].append(round(bnb.work_time,3))
    res['Timeout'].append(bnb.work_time>bnb.time_limit)
    res['Timeout (sec)'].append(bnb.time_limit)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=26.0), HTML(value='')))

# %%
result = pd.DataFrame(res)
result
# Out:
#                  graph  clique  time (sec)  Timeout  Timeout (sec)
# 0       c-fat200-1.clq      12       0.344    False           3600
# 1       c-fat200-2.clq      24       0.201    False           3600
# 2       c-fat200-5.clq      58       4.209    False           3600
# 3       c-fat500-1.clq      14       2.663    False           3600
# 4      c-fat500-10.clq     126       1.554    False           3600
# 5       c-fat500-2.clq      26       0.878    False           3600
# 6       c-fat500-5.clq      64       1.695    False           3600
# 7          MANN_a9.clq      16       0.059    False           3600
# 8       hamming6-2.clq      32       0.017    False           3600
# 9       hamming6-4.clq       4       0.473    False           3600
# 10  gen200_p0.9_44.clq      44    1448.245    False           3600
# 11  gen200_p0.9_55.clq      55       0.109    False           3600
# 12    san200_0.7_1.clq      30       0.109    False           3600
# 13    san200_0.7_2.clq      18       1.877    False           3600
# 14    san200_0.9_1.clq      70       0.027    False           3600
# 15    san200_0.9_2.clq      60       0.081    False           3600
# 16    san200_0.9_3.clq      44      28.980    False           3600
# 17     sanr200_0.7.clq      18    2395.129    False           3600
# 18          C125.9.clq      34     380.475    False           3600
# 19         keller4.clq      12      62.271    False           3600
# 20      brock200_1.clq      21    3600.013     True           3600
# 21      brock200_2.clq      12     229.652    False           3600
# 22      brock200_3.clq      15     734.231    False           3600
# 23      brock200_4.clq      17    1046.289    False           3600
# 24      p_hat300-1.clq       8     283.148    False           3600
# 25      p_hat300-2.clq      25    3199.344    False           3600

# %%
result.to_excel('res.xlsx', index=False)
